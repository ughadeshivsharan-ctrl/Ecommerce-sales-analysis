# %%
import pandas as pd
from sqlalchemy import create_engine
from urllib.parse import quote_plus
username = "root"
password = quote_plus("my_mysql_password")
host = "localhost"
database = "ecommerce_db"

engine = create_engine(f"mysql+pymysql://{username}:{password}@{host}/{database}")

files = {
    "olist_orders_dataset.csv": "olist_orders_dataset",
    "olist_order_items_dataset.csv": "olist_order_items_dataset",
    "olist_customers_dataset.csv": "olist_customers_dataset",
    "olist_products_dataset.csv": "olist_products_dataset",
    "olist_order_payments_dataset.csv": "olist_order_payments_dataset",
    "olist_order_reviews_dataset.csv": "olist_order_reviews_dataset",
    "olist_sellers_dataset.csv": "olist_sellers_dataset",
    "olist_geolocation_dataset.csv": "olist_geolocation_dataset",
    "product_category_name_translation.csv": "product_category_name_translation"
}

folder_path = "C:/Users/LENOVO/Downloads/archive/"
for file_name, table_name in files.items():
    print(f"Importing {file_name} ...")
    df = pd.read_csv(folder_path + file_name)
    df.to_sql(table_name, con=engine, if_exists="replace", index=False)
    print(f"{table_name} done — {len(df)} rows")

print("succesesfully import files!")
# Out:
# Importing olist_orders_dataset.csv ...
# olist_orders_dataset done — 99441 rows
# Importing olist_order_items_dataset.csv ...
# olist_order_items_dataset done — 112650 rows
# Importing olist_customers_dataset.csv ...
# olist_customers_dataset done — 99441 rows
# Importing olist_products_dataset.csv ...
# olist_products_dataset done — 32951 rows
# Importing olist_order_payments_dataset.csv ...
# olist_order_payments_dataset done — 103886 rows
# Importing olist_order_reviews_dataset.csv ...
# olist_order_reviews_dataset done — 99224 rows
# Importing olist_sellers_dataset.csv ...
# olist_sellers_dataset done — 3095 rows
# Importing olist_geolocation_dataset.csv ...
# olist_geolocation_dataset done — 1000163 rows
# Importing product_category_name_translation.csv ...
# product_category_name_translation done — 71 rows
# succesesfully import files!
